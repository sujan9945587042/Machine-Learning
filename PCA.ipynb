# %% [markdown]
# <a href="https://colab.research.google.com/github/sujan9945587042/Machine-Learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,roc_auc_score
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
df=pd.read_csv('/content/nba_final.csv')
df
# Out:
#        Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0     170     A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1      58     Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2     157     Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 3     352    Adreian Payne  paynead01   PF  NaN   25  MIN  18   0   7.5  ...
# 4      10  Al-Farouq Aminu  aminual01   PF  NaN   26  POR  61  25  29.1  ...
# ...   ...              ...        ...  ...  ...  ...  ...  ..  ..   ...  ...
# 1403  109     Zach Collins  colliza01    C  NaN   21  POR  77   0  17.6  ...
# 1404  294      Zach LaVine  lavinza01   SG  NaN   23  CHI  63  62  34.5  ...
# 1405  308      Zach Lofton  loftoza01   SG  NaN   26  DET   1   0   4.0  ...
# 1406  393    Zaza Pachulia  pachuza01    C  NaN   34  DET  68   3  12.9  ...
# 1407  457     Zhaire Smith  smithzh01   SG  NaN   19  PHI   6   2  18.5  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          1408 non-null   int64
#  1   Player.x    1408 non-null   object
#  2   Player_ID   1408 non-null   object
#  3   Pos1        1408 non-null   object
#  4   Pos2        12 non-null     object
#  5   Age         1408 non-null   int64
#  6   Tm          1408 non-null   object
#  7   G           1408 non-null   int64
#  8   GS          1408 non-null   int64
#  9   MP          1408 non-null   float64
#  10  FG          1408 non-null   float64
#  11  FGA         1408 non-null   float64
#  12  FG.         1404 non-null   float64
#  13  X3P         1408 non-null   float64
#  14  X3PA        1408 non-null   float64
#  15  X3P.        1309 non-null   float64
#  16  X2P         1408 non-null   float64
#  17  X2PA        1408 non-null   float64
#  18  X2P.        1393 non-null   float64
# ...

# %%
df.shape
# Out:
# (1408, 45)

# %%
df.isnull().sum() # by default axis=0
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0       6
# 1       5
# 2       5
# 3       3
# 4       3
#        ..
# 1403    1
# 1404    1
# 1405    4
# 1406    1
# 1407    1
# Length: 1408, dtype: int64

# %%
df[df.isnull().sum(axis=1) > 4]
# Out:
#        Rk       Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0     170   A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1      58   Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2     157   Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 8     464  Alan Williams  willial03    C  NaN   24  PHO  47   0  15.1  ...
# 9      65     Alec Burks  burksal01   SG  NaN   25  UTA  42   0  15.5  ...
# ...   ...            ...        ...  ...  ...  ...  ...  ..  ..   ...  ...
# 430   373    Willie Reed   reedwi02    C  NaN   26  MIA  71   5  14.5  ...
# 472   348      Ben Moore  moorebe01   PF  NaN   22  IND   2   0   4.5  ...
# 904   307    Tyler Lydon  lydonty01   PF  NaN   21  DEN   1   0   2.0  ...
# 1089  282    George King   kingge03   SF  NaN   25  PHO   1   0   6.0  ...
# 1388  152  Vince Edwards  edwarvi01   SF  NaN   22  HOU   2   0   8.0  ...
#
# ...

# %%
df[df.isnull().sum(axis=1) > 6]
# Out:
#        Rk       Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 27    341  Arinze Onuaku  onuakar01    C  NaN   29  ORL   8   0   3.5  ...
# 78    235   Damian Jones  jonesda03    C  NaN   21  GSW  10   0   8.5  ...
# 86    204   Danuel House  houseda01   SG  NaN   23  WAS   1   0   1.0  ...
# 169   360    Jakob Pöltl  poeltja01    C  NaN   21  TOR  54   4  11.6  ...
# 472   348      Ben Moore  moorebe01   PF  NaN   22  IND   2   0   4.5  ...
# 904   307    Tyler Lydon  lydonty01   PF  NaN   21  DEN   1   0   2.0  ...
# 1089  282    George King   kingge03   SF  NaN   25  PHO   1   0   6.0  ...
#
#       Conference   Role   Fvot  FRank  Pvot  PRank  Mvot  MRank  Score  Play
# 27           Est  Front    216    129   NaN    NaN   NaN    NaN   90.0    No
# 78          West  Front  12176     46   NaN    NaN   NaN    NaN   45.0    No
# 86           Est  Front    653    121   2.0   40.0   NaN    NaN   73.5    No
# ...

# %%
df=df[df.isnull().sum(axis=1)<=6]

# %%
df
# Out:
#        Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0     170     A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1      58     Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2     157     Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 3     352    Adreian Payne  paynead01   PF  NaN   25  MIN  18   0   7.5  ...
# 4      10  Al-Farouq Aminu  aminual01   PF  NaN   26  POR  61  25  29.1  ...
# ...   ...              ...        ...  ...  ...  ...  ...  ..  ..   ...  ...
# 1403  109     Zach Collins  colliza01    C  NaN   21  POR  77   0  17.6  ...
# 1404  294      Zach LaVine  lavinza01   SG  NaN   23  CHI  63  62  34.5  ...
# 1405  308      Zach Lofton  loftoza01   SG  NaN   26  DET   1   0   4.0  ...
# 1406  393    Zaza Pachulia  pachuza01    C  NaN   34  DET  68   3  12.9  ...
# 1407  457     Zhaire Smith  smithzh01   SG  NaN   19  PHI   6   2  18.5  ...
#
# ...

# %%
df['Pos2']=df['Pos2'].fillna('None')
# Out:
# <ipython-input-25-3918876534>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pos2']=df['Pos2'].fillna('None')

# %%
df['Pos2']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1403    None
# 1404    None
# 1405    None
# 1406    None
# 1407    None
# Name: Pos2, Length: 1401, dtype: object

# %%
df.isnull().sum()
# Out:
# Rk              0
# Player.x        0
# Player_ID       0
# Pos1            0
# Pos2            0
# Age             0
# Tm              0
# G               0
# GS              0
# MP              0
# FG              0
# FGA             0
# FG.             0
# X3P             0
# X3PA            0
# X3P.           92
# X2P             0
# X2PA            0
# X2P.           11
# eFG.            0
# FT              0
# FTA             0
# FT.            42
# ORB             0
# DRB             0
# TRB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# PF              0
# PTS             0
# Salary         61
# mean_views    132
# Season          0
# Conference      0
# Role            0
# Fvot            0
# FRank           0
# Pvot          156
# PRank         156
# Mvot          400
# MRank         400
# Score           0
# Play            0
# dtype: int64

# %%
df['Salary']
# Out:
# 0              NaN
# 1        2700000.0
# 2        4351320.0
# 3        2022240.0
# 4        7680965.0
#            ...
# 1403     3628920.0
# 1404    19500000.0
# 1405       77250.0
# 1406     2393887.0
# 1407     2615160.0
# Name: Salary, Length: 1401, dtype: float64

# %%
(61/1401)*100
# Out:
# 4.354032833690221

# %%
#if < 5% data fill the data,more than 5% delete them
#filling the values
#-->by mean and median =numerical
# mean-->col without outlier
#median-->col with outlier
#mode-->catogorical col
# using ml algoithms to predict and fill the missing values,knn inpedation,logistic reg,decison tree,random forest

# %%
df=df.fillna(0)

# %%
#df['Salary'].median()
# Out:
# 3183526.0

# %%
#df['Salary'].fillna(3183526.0)
# Out:
# 0              0.0
# 1        2700000.0
# 2        4351320.0
# 3        2022240.0
# 4        7680965.0
#            ...
# 1403     3628920.0
# 1404    19500000.0
# 1405       77250.0
# 1406     2393887.0
# 1407     2615160.0
# Name: Salary, Length: 1401, dtype: float64

# %%
#check for the duplicated
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#incase the duplicates are present
#df.drop_duplicated(inplace=True)
# if the rows are duplicare
#df.drop_duplicates(subset=['Pos2','conference','role',inplace=True])

# %%
df.drop(columns=['Player.x','Player_ID'],inplace=True)

# %%
#encoding the catogrical column values
obj_cols=df.select_dtypes('object').columns

# %%
le=LabelEncoder()
for col in obj_cols:
  df[col]=le.fit_transform(df[col])

# %%
#onehot encoder # most frequently used
#target
#binary encoder  # more than 15

# %%
        #ohe=OneHotEncoderEncoder()
        #for col in obj_cols:
          #df[col]=OHE.fit_transform(df[col])

# %%
df['Play'].value_counts()
# Out:
# Play
# 0    1328
# 1      73
# Name: count, dtype: int64

# %%
## machine learning process
X=df.drop(columns=['Play'])
y=df['Play']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=100)

# %%
#standadization/scaling/mean centering of the data
# always do the scaling of the data after splitting the data

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
## apply logistic regression on the data
log_reg=LogisticRegression()
log_reg.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(X_test_scaled)

# %%
# do not use accuracy_score when your data is imbaalnced
accuracy_score(y_test,y_pred)
# Out:
# 0.9715302491103203

# %%
roc_auc_score(y_test,y_pred)
# Out:
# np.float64(0.8276942355889724)

# %%
#now lets trnaform the data using PCA

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=0.95)

# %%
X_train_pca=pca.fit_transform(X_train_scaled)
X_test_pca=pca.transform(X_test_scaled)

# %%
X_train_pca.shape
# Out:
# (1120, 22)

# %%
pd.DataFrame(X_train_pca)
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.295448 -0.696433 -2.075801  1.071035 -0.076966  1.495680  1.525671
# 1     6.458682 -3.319194 -0.548379 -0.662028  1.534039  0.219862 -0.228630
# 2     2.853264  2.333875 -0.036240 -0.266254 -0.431569  2.984927  1.414984
# 3    -3.501380  2.150529  0.173848  1.585688 -0.249482 -0.741472 -0.884665
# 4    -4.394393 -1.361902  1.273493  1.623932 -1.694587 -0.461482  0.517384
# ...        ...       ...       ...       ...       ...       ...       ...
# 1115  3.528152  3.967726 -1.207241 -0.370291 -0.381460 -0.309489 -0.479815
# 1116 -2.886746 -1.465792  2.194175 -2.471307 -0.698232 -0.128499  1.634404
# 1117 -5.597668  0.318483  1.371465  2.632179 -1.870901 -0.170504  1.349299
# 1118 -4.890026 -0.209097  2.361138  1.592776 -2.907828  1.142470 -0.122689
# 1119 -4.366486 -1.286146  0.591555 -0.258470  1.169340  1.155884  1.387332
#
# ...

# %%
log_reg2=LogisticRegression()

# %%
log_reg2.fit(X_train_pca,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_2=log_reg2.predict(X_test_pca)

# %%
roc_auc_score(y_test,y_pred_2)
# Out:
# np.float64(0.8943609022556391)
